# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://api.worldbank.org/v2/country/COL/indicator/FP.CPI.TOTL.ZG?format=json&per_page=100"

# %%
respuesta = requests.get(url)

# %%
if respuesta.status_code == 200:
    data = respuesta.json()
    registros = data[1]

    df_ipc = pd.DataFrame(registros)[["date","value"]]
    df_ipc.columns = ["Año", "IPC (%)"]
    df_ipc = df_ipc.dropna().sort_values("Año", ascending=False)
    print(df_ipc.head())
else:
    print("Error al consultar la API:", respuesta.status_code)
# Out:
#     Año    IPC (%)
# 0  2024   6.609086
# 1  2023  11.735904
# 2  2022  10.177231
# 3  2021   3.495058
# 4  2020   2.526635

# %%
df_ipc
# Out:
#      Año    IPC (%)
# 0   2024   6.609086
# 1   2023  11.735904
# 2   2022  10.177231
# 3   2021   3.495058
# 4   2020   2.526635
# 5   2019   3.523019
# 6   2018   3.240569
# 7   2017   4.314313
# 8   2016   7.513460
# 9   2015   4.989831
# 10  2014   2.898838
# 11  2013   2.016992
# 12  2012   3.169302
# 13  2011   3.415033
# 14  2010   2.272002
# 15  2009   4.202517
# 16  2008   6.996885
# 17  2007   5.544385
# 18  2006   4.293424
# 19  2005   5.051020
# 20  2004   5.904020
# 21  2003   7.129789
# 22  2002   6.351507
# 23  2001   7.965561
# 24  2000   9.225348
# 25  1999  10.873687
# 26  1998  18.676980
# 27  1997  18.470022
# 28  1996  20.797576
# 29  1995  20.891793
# 30  1994  22.846242
# 31  1993  22.442483
# 32  1992  27.010627
# 33  1991  30.387820
# 34  1990  29.152025
# 35  1989  25.867548
# 36  1988  28.108397
# 37  1987  23.302028
# 38  1986  18.842463
# 39  1985  24.090174
# 40  1984  16.161617
# 41  1983  19.597317
# 42  1982  24.720988
# 43  1981  27.453762
# 44  1980  26.552653
# 45  1979  24.134076
# 46  1978  17.763159
# 47  1977  33.802818
# 48  1976  19.831225
# 49  1975  23.437503
# 50  1974  23.870957
# 51  1973  22.529649
# 52  1972  12.444459
# 53  1971  11.940262

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))
sns.lineplot(data=df_ipc, x="Año", y="IPC (%)", marker="o")
plt.title("Evolución histórica del IPC en Colombia")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import shutil
shutil.rmtree("ipc-colombia")

# %%
# !git clone https://github.com/fbornacelli23/ipc-colombia.git
